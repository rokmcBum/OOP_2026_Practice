# %% [markdown]
# <a href="https://colab.research.google.com/github/ElionLAB/OOP_2026_Practice/blob/main/ch_01/src/Lec_1_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 환경 설정 — Google Colab / 로컬 환경 자동 감지
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    pass  # 이 노트북은 추가 패키지가 필요하지 않습니다.
else:
    print('로컬 환경: conda activate OOP 상태인지 확인하세요.')

# %%
# Attributes and Instantiation in Code

# TO DO
class Apple:

# %%
# Orange
class Orange:
    def __init__(self, color: str, weight: float):
        # These are attributes describing the state
        self.color = color
        self.weight = weight
        self.barrel = None # Association attribute

# Customer
class Customer:
    def __init__(self, name: str):
        self.name = name
        self.balance = 100.0  # Initial balance for simplicity

    def bill(self, amount: float) -> None:
        # Method to modify the customer's balance
        self.balance -= amount

# Methods in Action & Object Interaction
class Basket:
    # TO DO
    def __init__(self, location: str):

    # TO DO
    def add_orange(self, orange: Orange) -> None:
        # Behavior modifying internal state

    # TO DO
    def sell(self, customer: Customer) -> None:
        # Complex interaction with another object

    def calculate_price(self) -> float:
        # Simple pricing logic based on weight
        return sum(orange.weight * 0.5 for orange in self.oranges)

# %%
# practice# Create instances of Orange and Customer
orange1 = Orange(color="red", weight=0.5)
customer1 = Customer(name="Alice")
# Create a Basket and add the orange to it
basket = Basket(location="Market")
basket.add_orange(orange1)
# Sell the basket to the customer
basket.sell(customer1)
# Check the customer's balance after the purchase
print(f"{customer1.name}'s balance after purchase: ${customer1.balance:.2f}")
# Out:
# Alice's balance after purchase: $99.75
